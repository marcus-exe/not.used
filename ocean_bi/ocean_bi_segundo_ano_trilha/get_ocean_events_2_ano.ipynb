# %%
from utils import *

import pandas as pd

# %%
sql = r"""
SELECT 
    eve_id,
    eve_title,
    eve_vacancy,
    eve_workload,
    eve_start_date,
    eve_end_date,
    eve_start_hour,
    eve_end_hour,
    eve_enrollment_start,
    eve_enrollment_end,
    eve_speaker_name,
    eve_audience,
    eve_requirements,
    eve_creation_date,
    fre_enr_stu_id,
    fre_cla_id,
    fre_status,
    stu_session,
    stu_name,
    stu_cpf,
    stu_phone,
    stu_gender,
    stu_birth_date,
    stu_creation_date,
    stu_last_login,
    stu_email
FROM
    event,
    frequency,
    student
WHERE
    eve_id = fre_enr_eve_id
        AND stu_id = fre_enr_stu_id
        AND eve_start_date BETWEEN '2021.04.23' AND '2021.12.31'
    """

db_con = OceanDB()
df = pd.read_sql(sql, db_con.mydb)
df.to_csv('ocean_online_events_second_year.csv', index=False)  
df
# Out:
#        eve_id                                        eve_title  eve_vacancy  \
# 0        2296  Tizen: Ferramenta e Ambiente de Desenvolvimento          500
# 1        2296  Tizen: Ferramenta e Ambiente de Desenvolvimento          500
# 2        2296  Tizen: Ferramenta e Ambiente de Desenvolvimento          500
# 3        2296  Tizen: Ferramenta e Ambiente de Desenvolvimento          500
# 4        2296  Tizen: Ferramenta e Ambiente de Desenvolvimento          500
# ...       ...                                              ...          ...
# 88797    2795     Ocean Launch - T5 - Métricas do Produto - T2           15
# 88798    2795     Ocean Launch - T5 - Métricas do Produto - T2           15
# 88799    2795     Ocean Launch - T5 - Métricas do Produto - T2           15
# 88800    2795     Ocean Launch - T5 - Métricas do Produto - T2           15
# 88801    2795     Ocean Launch - T5 - Métricas do Produto - T2           15
#
# ...

# %%
# Out:
#      eve_id                                          eve_title  eve_vacancy  \
# 0      1828  Palestra: Introdução ao Desenvolvimento de Jog...          500
# 1      1830  M1 - Inteligência artificial: entenda o que é ...          500
# 2      1831  Palestra: Assistente Virtual de Voz em Bixby -...          500
# 3      1832       I1 -  Introdução a Internet das Coisas (IoT)          500
# 4      1833  M2 - Inteligência Artificial - Fundamentos da ...          500
# ..      ...                                                ...          ...
# 456    2295  Assistente Virtual de Voz em Bixby - Trazendo ...          500
# 457    2300               Introdução ao Frontend Web com React          500
# 458    2301              Laboratório de Frontend Web com React          500
# 459    2308                           Ocean Beginner (Parte 3)          180
# 460    2309                           Ocean Beginner (Parte 4)          180
#
# ...
